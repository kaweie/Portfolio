# %%
import cv2
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os
import scipy

# %% [markdown]
# # Images

# %%
plt.imshow(plt.imread('comet.jpg'))
plt.show()

plt.imshow(plt.imread('puppy-dog.jpg'))
plt.show()

# %%
DIR = "c:/Users/kaweie/Documents/PetImages"
categories = ["Cat", "Dog"]
img_size = 70

def prepare(filepath):
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (img_size,img_size))
    return new_array.reshape(-1, img_size, img_size,1)

model = tf.keras.models.load_model('64x3-CNN.model')
prediction = model.predict([prepare('comet.jpg')])

# %%
print("This is a %s" %(categories[int(prediction[0][0])]))
plt.imshow(plt.imread('comet.jpg'))
plt.show()
# Out:
# This is a Cat

# %%
DIR = "c:/Users/kaweie/Documents/PetImages"
categories = ["Cat", "Dog"]
img_size = 70

def prepare(filepath):
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (img_size,img_size))
    return new_array.reshape(-1, img_size, img_size,1)

model = tf.keras.models.load_model('64x3-CNN.model')
prediction = model.predict([prepare('puppy-dog.jpg')])

# %%
print("This is a %s" %(categories[int(prediction[0][0])]))
plt.imshow(plt.imread('puppy-dog.jpg'))
plt.show()
# Out:
# This is a Dog
